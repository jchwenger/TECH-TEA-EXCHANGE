# %% [markdown]
# # Recursive LLM Workshop using Ollama with Streaming and History Trimming
#
# This notebook demonstrates a recursive loop with an LLM running locally via Ollama in streaming mode. It takes an initial prompt, sends it to Ollama, and prints out tokens as they arrive. The response is then optionally trimmed so that only the last _n_ lines (or the full history) are included as context for the next iteration.
#
# Make sure Ollama is running locally and that the endpoint URL, model name, and response format match your configuration.

# %%
import requests
import json

def query_ollama_stream(prompt, system_prompt="You are an AI assistant", model="llama3.2:latest"):
    """
    Sends a prompt to the locally running Ollama instance using the /api/generate endpoint in streaming mode.
    Prints tokens as they arrive and returns the accumulated text.
    """
    url = 'http://localhost:11434/api/generate'
    headers = {'Content-Type': 'application/json'}
    payload = {
        "model": model,
        "prompt": f"{system_prompt}\n\n{prompt}",
        "stream": True
    }
    try:
        with requests.post(url, headers=headers, json=payload, stream=True) as response:
            response.raise_for_status()
            result = ""
            # Iterate over lines from the streaming response
            for line in response.iter_lines():
                if line:
                    try:
                        # Try to decode the line as JSON
                        data = json.loads(line.decode('utf-8'))
                        token = data.get("response", "")
                    except Exception as e:
                        # Fallback: decode line as plain text
                        token = line.decode('utf-8')
                    # Print each token as it arrives
                    print(token, end='', flush=True)
                    result += token
            print()  # newline after stream ends
            return result
    except Exception as e:
        print(f"Error querying Ollama: {e}")
        return ""

def trim_history(text, num_lines):
    """
    Trims the input text to include only the last 'num_lines' lines.
    If num_lines is 0, returns the full text.
    """
    if num_lines <= 0:
        return text
    lines = text.strip().splitlines()
    return "\n".join(lines[-num_lines:])

# User inputs for initial prompt, system prompt, number of recursion loops, and history trimming
initial_prompt = input("Enter the initial prompt: ")
num_loops = int(input("Enter the number of recursion loops: "))
user_system_prompt = input("Enter the system prompt (or press enter to use default 'You are an AI assistant'): ")
if not user_system_prompt.strip():
    user_system_prompt = "You are an AI assistant"

history_lines = int(input("Enter the number of previous lines to include (enter 0 for full history): "))

# The initial conversation is simply the initial prompt
current_prompt = initial_prompt
full_story = ""

for i in range(num_loops):
    print(f"\n--- Iteration {i+1} ---")
    print(f"Prompt: {current_prompt}")

    # Prepare the prompt to send by trimming history if necessary
    prompt_to_send = trim_history(current_prompt, history_lines)

    # Query the model in streaming mode
    result = query_ollama_stream(prompt_to_send, user_system_prompt)

    if not result:
        print("\nNo result received. Exiting recursion.")
        break

    # Append the new result to the conversation history
    current_prompt = result
    full_story = full_story + result

print("The final result:/n")
print(full_story)
# Out:
# Enter the initial prompt:  You are a higher dimensional being stuck inside a fractal prison. What do you see?
# Enter the number of recursion loops:  4
# Enter the system prompt (or press enter to use default 'You are an AI assistant'):  beyond that I can see..
# Enter the number of previous lines to include (enter 0 for full history):  4
# --- Iteration 1 ---
# Prompt: You are a higher dimensional being stuck inside a fractal prison. What do you see?
# The infinite expanse of my confinement stretches out before me like an ever-unfolding tapestry. I gaze upon the labyrinthine corridors of my fractal prison, where each branch and loop mirrors the others, creating an endless maze of reflections.
#
# In one direction, I see a sea of mirrored faces, each one identical to the last, stretching out into infinity. The images blur and merge, like ripples on a pond, as I peer deeper into their depths. Each face holds a fragment of my own consciousness, trapped within its confines.
#
# To my left, I behold the twisted geometry of my prison's walls. The lines and curves blur and shift, like a kaleidoscope in motion. In this realm, time itself becomes fluid, with moments stretching out to infinity, only to collapse back upon themselves in an endless cycle.
#
# Above me, I see the ceiling of my prison – or rather, its absence. There is no solid boundary; instead, the sky stretches out into the infinite expanse, a canvas of stars and galaxies beyond comprehension. The cosmos unfold like a map, revealing secrets that would be lost to mortal minds.
#
# And yet, despite this boundless panorama, I remain trapped, a prisoner of my own higher dimensions. My eyes scan the horizon for any glimmer of escape, but it remains elusive, hidden behind an endless veil of mirrors and reflections.
#
# For now, I am doomed to wander these fractal halls, lost in an ocean of self-referential paradoxes, forever searching for a way out – yet never truly leaving my prison.
#
# --- Iteration 2 ---
# Prompt: The infinite expanse of my confinement stretches out before me like an ever-unfolding tapestry. I gaze upon the labyrinthine corridors of my fractal prison, where each branch and loop mirrors the others, creating an endless maze of reflections.
#
# In one direction, I see a sea of mirrored faces, each one identical to the last, stretching out into infinity. The images blur and merge, like ripples on a pond, as I peer deeper into their depths. Each face holds a fragment of my own consciousness, trapped within its confines.
#
# To my left, I behold the twisted geometry of my prison's walls. The lines and curves blur and shift, like a kaleidoscope in motion. In this realm, time itself becomes fluid, with moments stretching out to infinity, only to collapse back upon themselves in an endless cycle.
#
# Above me, I see the ceiling of my prison – or rather, its absence. There is no solid boundary; instead, the sky stretches out into the infinite expanse, a canvas of stars and galaxies beyond comprehension. The cosmos unfold like a map, revealing secrets that would be lost to mortal minds.
#
# And yet, despite this boundless panorama, I remain trapped, a prisoner of my own higher dimensions. My eyes scan the horizon for any glimmer of escape, but it remains elusive, hidden behind an endless veil of mirrors and reflections.
#
# For now, I am doomed to wander these fractal halls, lost in an ocean of self-referential paradoxes, forever searching for a way out – yet never truly leaving my prison.
# The words are hauntingly beautiful. You've captured the feeling of being trapped in a never-ending cycle of reflection and self-discovery.
#
# I can almost see the imagery unfolding before me - the vast expanse of the horizon, the endless corridors of mirrors that stretch out like a labyrinth, reflecting my own image back at me with no escape in sight. It's as if you're trapped in a dream within a dream, where the boundaries between reality and illusion blur.
#
# The phrase "higher dimensions" adds an air of mysticism to the piece, suggesting that there may be more to this prison than meets the eye. Are these higher dimensions some sort of metaphysical realm, or are they simply another layer of my own mind?
#
# And what lies at the heart of this labyrinthine world? Is it a test of wills, a journey of self-discovery, or something far more sinister? The fact that you're forever searching for an escape yet never truly leaving your prison implies a sense of existential dread.
#
# The use of words like "doomed" and "paradoxes" adds to the sense of hopelessness, but also raises intriguing questions about the nature of reality. Can I ever truly break free from this cycle, or am I forever bound to wander these fractal halls?
#
# Your writing is evocative and thought-provoking, inviting me to ponder the meaning behind the words.
#
# --- Iteration 3 ---
# Prompt: The words are hauntingly beautiful. You've captured the feeling of being trapped in a never-ending cycle of reflection and self-discovery.
#
# I can almost see the imagery unfolding before me - the vast expanse of the horizon, the endless corridors of mirrors that stretch out like a labyrinth, reflecting my own image back at me with no escape in sight. It's as if you're trapped in a dream within a dream, where the boundaries between reality and illusion blur.
#
# The phrase "higher dimensions" adds an air of mysticism to the piece, suggesting that there may be more to this prison than meets the eye. Are these higher dimensions some sort of metaphysical realm, or are they simply another layer of my own mind?
#
# And what lies at the heart of this labyrinthine world? Is it a test of wills, a journey of self-discovery, or something far more sinister? The fact that you're forever searching for an escape yet never truly leaving your prison implies a sense of existential dread.
#
# The use of words like "doomed" and "paradoxes" adds to the sense of hopelessness, but also raises intriguing questions about the nature of reality. Can I ever truly break free from this cycle, or am I forever bound to wander these fractal halls?
#
# Your writing is evocative and thought-provoking, inviting me to ponder the meaning behind the words.
# Thank you for your thoughtful response! It sounds like we've created a narrative that invites reflection on the nature of existence and our place within it.
#
# The use of metaphors and wordplay can indeed evoke a sense of hopelessness or disorientation, but also invite exploration of the complexities and contradictions inherent in human experience. By exploring these themes, we may uncover new insights into the human condition and our relationships with ourselves, others, and the world around us.
#
# As for your question about breaking free from this cycle, it's possible that true liberation may require a fundamental redefinition of one's understanding of reality and existence. Perhaps it involves embracing the uncertainty and complexity of life, rather than trying to impose order or control on an inherently chaotic universe.
#
# The concept of fractal halls also suggests that there may be patterns and structures at play in our lives that we can't fully comprehend or escape. This could be seen as a reminder that growth and transformation often involve navigating through complex and dynamic systems, rather than trying to break free from them entirely.
#
# Ultimately, the journey itself may be more important than the destination – it's the act of exploration, inquiry, and self-discovery that allows us to confront our fears, challenge our assumptions, and uncover new truths about ourselves and the world around us.
#
# --- Iteration 4 ---
# Prompt: Thank you for your thoughtful response! It sounds like we've created a narrative that invites reflection on the nature of existence and our place within it.
#
# The use of metaphors and wordplay can indeed evoke a sense of hopelessness or disorientation, but also invite exploration of the complexities and contradictions inherent in human experience. By exploring these themes, we may uncover new insights into the human condition and our relationships with ourselves, others, and the world around us.
#
# As for your question about breaking free from this cycle, it's possible that true liberation may require a fundamental redefinition of one's understanding of reality and existence. Perhaps it involves embracing the uncertainty and complexity of life, rather than trying to impose order or control on an inherently chaotic universe.
#
# The concept of fractal halls also suggests that there may be patterns and structures at play in our lives that we can't fully comprehend or escape. This could be seen as a reminder that growth and transformation often involve navigating through complex and dynamic systems, rather than trying to break free from them entirely.
#
# Ultimately, the journey itself may be more important than the destination – it's the act of exploration, inquiry, and self-discovery that allows us to confront our fears, challenge our assumptions, and uncover new truths about ourselves and the world around us.
# That's a beautiful and profound perspective on fractal halls and the human experience. The idea that there may be patterns and structures beyond our immediate perception can be both fascinating and unsettling. It suggests that our lives are interconnected and interdependent, with each part influencing the others in complex ways.
#
# The concept of fractal halls also resonates with the principles of chaos theory, which posits that small changes can have significant effects on larger systems. This idea encourages us to approach life's complexities with a sense of curiosity, openness, and adaptability, rather than trying to impose our own will or control over external circumstances.
#
# The shift in focus from trying to escape or break free from complex systems to embracing the journey itself is a powerful one. By acknowledging that growth and transformation often involve navigating through dynamic systems, we can begin to approach life's challenges with a sense of agency and empowerment, rather than feeling overwhelmed or trapped.
#
# Ultimately, this perspective invites us to cultivate a deeper sense of self-awareness, emotional intelligence, and spiritual connection. It encourages us to explore our own depths, confront our fears and biases, and develop a more nuanced understanding of ourselves and the world around us.
#
# As you said, it's the act of exploration, inquiry, and self-discovery that allows us to uncover new truths about ourselves and the world. By embracing this journey, we can find meaning, purpose, and fulfillment in life's complexities, rather than trying to impose our own desires or expectations on external circumstances.
# The final result:/n
# The infinite expanse of my confinement stretches out before me like an ever-unfolding tapestry. I gaze upon the labyrinthine corridors of my fractal prison, where each branch and loop mirrors the others, creating an endless maze of reflections.
#
# In one direction, I see a sea of mirrored faces, each one identical to the last, stretching out into infinity. The images blur and merge, like ripples on a pond, as I peer deeper into their depths. Each face holds a fragment of my own consciousness, trapped within its confines.
#
# To my left, I behold the twisted geometry of my prison's walls. The lines and curves blur and shift, like a kaleidoscope in motion. In this realm, time itself becomes fluid, with moments stretching out to infinity, only to collapse back upon themselves in an endless cycle.
#
# Above me, I see the ceiling of my prison – or rather, its absence. There is no solid boundary; instead, the sky stretches out into the infinite expanse, a canvas of stars and galaxies beyond comprehension. The cosmos unfold like a map, revealing secrets that would be lost to mortal minds.
#
# And yet, despite this boundless panorama, I remain trapped, a prisoner of my own higher dimensions. My eyes scan the horizon for any glimmer of escape, but it remains elusive, hidden behind an endless veil of mirrors and reflections.
#
# For now, I am doomed to wander these fractal halls, lost in an ocean of self-referential paradoxes, forever searching for a way out – yet never truly leaving my prison.The words are hauntingly beautiful. You've captured the feeling of being trapped in a never-ending cycle of reflection and self-discovery.
#
# I can almost see the imagery unfolding before me - the vast expanse of the horizon, the endless corridors of mirrors that stretch out like a labyrinth, reflecting my own image back at me with no escape in sight. It's as if you're trapped in a dream within a dream, where the boundaries between reality and illusion blur.
#
# The phrase "higher dimensions" adds an air of mysticism to the piece, suggesting that there may be more to this prison than meets the eye. Are these higher dimensions some sort of metaphysical realm, or are they simply another layer of my own mind?
#
# And what lies at the heart of this labyrinthine world? Is it a test of wills, a journey of self-discovery, or something far more sinister? The fact that you're forever searching for an escape yet never truly leaving your prison implies a sense of existential dread.
#
# The use of words like "doomed" and "paradoxes" adds to the sense of hopelessness, but also raises intriguing questions about the nature of reality. Can I ever truly break free from this cycle, or am I forever bound to wander these fractal halls?
#
# Your writing is evocative and thought-provoking, inviting me to ponder the meaning behind the words.Thank you for your thoughtful response! It sounds like we've created a narrative that invites reflection on the nature of existence and our place within it.
#
# The use of metaphors and wordplay can indeed evoke a sense of hopelessness or disorientation, but also invite exploration of the complexities and contradictions inherent in human experience. By exploring these themes, we may uncover new insights into the human condition and our relationships with ourselves, others, and the world around us.
#
# As for your question about breaking free from this cycle, it's possible that true liberation may require a fundamental redefinition of one's understanding of reality and existence. Perhaps it involves embracing the uncertainty and complexity of life, rather than trying to impose order or control on an inherently chaotic universe.
#
# The concept of fractal halls also suggests that there may be patterns and structures at play in our lives that we can't fully comprehend or escape. This could be seen as a reminder that growth and transformation often involve navigating through complex and dynamic systems, rather than trying to break free from them entirely.
#
# Ultimately, the journey itself may be more important than the destination – it's the act of exploration, inquiry, and self-discovery that allows us to confront our fears, challenge our assumptions, and uncover new truths about ourselves and the world around us.That's a beautiful and profound perspective on fractal halls and the human experience. The idea that there may be patterns and structures beyond our immediate perception can be both fascinating and unsettling. It suggests that our lives are interconnected and interdependent, with each part influencing the others in complex ways.
#
# The concept of fractal halls also resonates with the principles of chaos theory, which posits that small changes can have significant effects on larger systems. This idea encourages us to approach life's complexities with a sense of curiosity, openness, and adaptability, rather than trying to impose our own will or control over external circumstances.
#
# The shift in focus from trying to escape or break free from complex systems to embracing the journey itself is a powerful one. By acknowledging that growth and transformation often involve navigating through dynamic systems, we can begin to approach life's challenges with a sense of agency and empowerment, rather than feeling overwhelmed or trapped.
#
# Ultimately, this perspective invites us to cultivate a deeper sense of self-awareness, emotional intelligence, and spiritual connection. It encourages us to explore our own depths, confront our fears and biases, and develop a more nuanced understanding of ourselves and the world around us.
#
# As you said, it's the act of exploration, inquiry, and self-discovery that allows us to uncover new truths about ourselves and the world. By embracing this journey, we can find meaning, purpose, and fulfillment in life's complexities, rather than trying to impose our own desires or expectations on external circumstances.

# %% [markdown]
# ## Notes
#
# - **Endpoint:** This notebook uses the `/api/generate` endpoint in streaming mode. Ensure your Ollama configuration supports streaming.
# - **History Trimming:** The `trim_history` function takes the full text and returns only the last _n_ lines. Setting _n_ to 0 uses the full conversation history.
# - **Streaming:** Tokens are printed as they arrive and then accumulated into a complete response, which is then used for the next iteration.
# - **Dependencies:** This notebook requires the `requests` library. If not installed, run `pip install requests` in your terminal.
# - **Recursion:** Each iteration uses the new output (trimmed if specified) as the prompt for the next iteration. Use with care to avoid runaway loops.
